# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Penyebab Kematian di Indonesia yang Dilaporkan - Raw.csv")
df.head()
# Out:
#              Cause                           Type  Year  Data Redundancy  \
# 0  Abrasi Air Laut                   Bencana Alam  2012                1
# 1             AIDS  Bencana Non Alam dan Penyakit  2000                1
# 2             AIDS  Bencana Non Alam dan Penyakit  2001                1
# 3             AIDS  Bencana Non Alam dan Penyakit  2002                1
# 4             AIDS  Bencana Non Alam dan Penyakit  2003                5
#
#    Total Deaths                                 Source Page at Source  \
# 0             0  Profil Kesehatan Indonesia Tahun 2012  Lampiran 3.38
# 1            47  Profil Kesehatan Indonesia Tahun 2004             78
# 2            99  Profil Kesehatan Indonesia Tahun 2004             78
# 3           100  Profil Kesehatan Indonesia Tahun 2004             78
# 4           261  Profil Kesehatan Indonesia Tahun 2004             78
#
#                                           Source URL
# 0  https://pusdatin.kemkes.go.id/download.php?fil...
# 1  https://pusdatin.kemkes.go.id/download.php?fil...
# 2  https://pusdatin.kemkes.go.id/download.php?fil...
# 3  https://pusdatin.kemkes.go.id/download.php?fil...
# 4  https://pusdatin.kemkes.go.id/download.php?fil...

# %%
to_drop = ['Source URL','Source','Cause','Page at Source']

# %%
df.drop(to_drop, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1062 entries, 0 to 1061
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             1062 non-null   object
#  1   Year             1062 non-null   int64
#  2   Data Redundancy  1062 non-null   int64
#  3   Total Deaths     1062 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 33.3+ KB

# %%
x = df.drop(["Type"], axis=1)
x.head(11)
# Out:
#     Year  Data Redundancy  Total Deaths
# 0   2012                1             0
# 1   2000                1            47
# 2   2001                1            99
# 3   2002                1           100
# 4   2003                5           261
# 5   2003                5           261
# 6   2003                5           261
# 7   2003                5           261
# 8   2003                5           261
# 9   2004                5           361
# 10  2004                5           361

# %%
y = df["Type"]
y.head(11)
# Out:
# 0                      Bencana Alam
# 1     Bencana Non Alam dan Penyakit
# 2     Bencana Non Alam dan Penyakit
# 3     Bencana Non Alam dan Penyakit
# 4     Bencana Non Alam dan Penyakit
# 5     Bencana Non Alam dan Penyakit
# 6     Bencana Non Alam dan Penyakit
# 7     Bencana Non Alam dan Penyakit
# 8     Bencana Non Alam dan Penyakit
# 9     Bencana Non Alam dan Penyakit
# 10    Bencana Non Alam dan Penyakit
# Name: Type, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

modelnb = GaussianNB()

# %%
nbtrain = modelnb.fit(x, y)
df.head(11)
# Out:
#                              Type  Year  Data Redundancy  Total Deaths
# 0                    Bencana Alam  2012                1             0
# 1   Bencana Non Alam dan Penyakit  2000                1            47
# 2   Bencana Non Alam dan Penyakit  2001                1            99
# 3   Bencana Non Alam dan Penyakit  2002                1           100
# 4   Bencana Non Alam dan Penyakit  2003                5           261
# 5   Bencana Non Alam dan Penyakit  2003                5           261
# 6   Bencana Non Alam dan Penyakit  2003                5           261
# 7   Bencana Non Alam dan Penyakit  2003                5           261
# 8   Bencana Non Alam dan Penyakit  2003                5           261
# 9   Bencana Non Alam dan Penyakit  2004                5           361
# 10  Bencana Non Alam dan Penyakit  2004                5           361

# %%
x_test = df.drop(["Type"], axis=1)
x_test.head(11)
# Out:
#     Year  Data Redundancy  Total Deaths
# 0   2012                1             0
# 1   2000                1            47
# 2   2001                1            99
# 3   2002                1           100
# 4   2003                5           261
# 5   2003                5           261
# 6   2003                5           261
# 7   2003                5           261
# 8   2003                5           261
# 9   2004                5           361
# 10  2004                5           361

# %%
y_uji = df["Type"]
y_uji.head(11)
# Out:
# 0                      Bencana Alam
# 1     Bencana Non Alam dan Penyakit
# 2     Bencana Non Alam dan Penyakit
# 3     Bencana Non Alam dan Penyakit
# 4     Bencana Non Alam dan Penyakit
# 5     Bencana Non Alam dan Penyakit
# 6     Bencana Non Alam dan Penyakit
# 7     Bencana Non Alam dan Penyakit
# 8     Bencana Non Alam dan Penyakit
# 9     Bencana Non Alam dan Penyakit
# 10    Bencana Non Alam dan Penyakit
# Name: Type, dtype: object

# %%
Y_predict = nbtrain.predict(x_test)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# Prediksi Naive Bayes :  ['Bencana Sosial' 'Bencana Non Alam dan Penyakit'
#  'Bencana Non Alam dan Penyakit' ... 'Bencana Sosial' 'Bencana Sosial'
#  'Bencana Sosial']

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_uji, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# Akurasi Naive Bayes :  0.6346516007532956

# %%
from sklearn.metrics import classification_report
print(classification_report(y_uji, Y_predict))
# Out:
#                                precision    recall  f1-score   support
#
#                  Bencana Alam       0.29      0.17      0.21       148
# Bencana Non Alam dan Penyakit       0.98      0.70      0.82       894
#                Bencana Sosial       0.06      0.95      0.11        20
#
#                      accuracy                           0.63      1062
#                     macro avg       0.44      0.61      0.38      1062
#                  weighted avg       0.87      0.63      0.72      1062
